# %% [markdown]
# ## 1.3 Cleaning and Data Preparation
#
# In this phase we check for null values, duplicates, or structural anomalies to delete it and improve the dataset of `person_voice_works`, `profiles`, `ratings`, `recommendations` and `stats`.

# %% [markdown]
# ---

# %% [markdown]
# ### Loading Data from csv files

# %%
from lib.dbconnection import create_db_engine
from lib import readSaveCsv as rsc
from lib.heavyDataCleaning import process_heavy_data

input_csv = '../../data/ratings.csv'  # Assicurati che il percorso sia corretto
output_parquet = '../../cleaned_data/ratings_cleaned.parquet'

process_heavy_data(input_csv, output_parquet)

engine = create_db_engine()


person_voice_works = rsc.import_data(engine, "person_voice_works")
profiles = rsc.import_data(engine, "profiles")
recommendations = rsc.import_data(engine, "recommendations")
stats = rsc.import_data(engine, "stats")
# Out:
# Pulizia completata: ../../cleaned_data/ratings_cleaned.parquet
# Successo: Dati letti correttamente.
# Successo: Dati letti correttamente.
# Successo: Dati letti correttamente.
# Successo: Dati letti correttamente.

# %% [markdown]
# ---

# %% [markdown]
# ### Checking DataFrames info and visualise first rows

# %%
person_voice_works.info()
print('\n')
profiles.info()
print('\n')
recommendations.info()
print('\n')
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489516 entries, 0 to 489515
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   person_mal_id     489516 non-null  int64
#  1   role              489516 non-null  object
#  2   anime_mal_id      489516 non-null  int64
#  3   character_mal_id  489516 non-null  int64
#  4   language          489516 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 18.7+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337155 entries, 0 to 337154
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   username       337154 non-null  object
#  1   gender         166279 non-null  object
#  2   birthday       121329 non-null  object
#  3   location       337155 non-null  object
#  4   joined         335479 non-null  object
#  5   watching       335477 non-null  object
#  6   completed      335477 non-null  object
#  7   on_hold        335477 non-null  object
#  8   dropped        335477 non-null  object
#  9   plan_to_watch  335477 non-null  object
# dtypes: object(10)
# memory usage: 25.7+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105249 entries, 0 to 105248
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   mal_id                 105249 non-null  int64
#  1   recommendation_mal_id  105249 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28955 entries, 0 to 28954
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   mal_id               28955 non-null  int64
#  1   watching             28955 non-null  int64
#  2   completed            28955 non-null  int64
#  3   on_hold              28955 non-null  int64
#  4   dropped              28955 non-null  int64
#  5   plan_to_watch        28955 non-null  int64
#  6   total                28955 non-null  int64
#  7   score_1_votes        28525 non-null  float64
#  8   score_1_percentage   28525 non-null  float64
#  9   score_2_votes        28525 non-null  float64
#  10  score_2_percentage   28525 non-null  float64
#  11  score_3_votes        28525 non-null  float64
#  12  score_3_percentage   28525 non-null  float64
#  13  score_4_votes        28525 non-null  float64
#  14  score_4_percentage   28525 non-null  float64
#  15  score_5_votes        28525 non-null  float64
#  16  score_5_percentage   28525 non-null  float64
#  17  score_6_votes        28525 non-null  float64
#  18  score_6_percentage   28525 non-null  float64
#  19  score_7_votes        28525 non-null  float64
#  20  score_7_percentage   28525 non-null  float64
#  21  score_8_votes        28525 non-null  float64
#  22  score_8_percentage   28525 non-null  float64
#  23  score_9_votes        28525 non-null  float64
#  24  score_9_percentage   28525 non-null  float64
#  25  score_10_votes       28525 non-null  float64
#  26  score_10_percentage  28525 non-null  float64
# dtypes: float64(20), int64(7)
# memory usage: 6.0 MB

# %%
person_voice_works
# Out:
#         person_mal_id        role  anime_mal_id  character_mal_id  language
# 0                   1        Main         55830              2514  Japanese
# 1                   1  Supporting         60602              2822  Japanese
# 2                   1  Supporting         59229            140499  Japanese
# 3                   1  Supporting         60427            275856  Japanese
# 4                   1  Supporting         62067            190335  Japanese
# ...               ...         ...           ...               ...       ...
# 489511          89839  Supporting         40111            274622  Mandarin
# 489512          89840  Supporting         60544            266412  Mandarin
# 489513          89841  Supporting         60544            266416  Mandarin
# 489514          89842  Supporting         36896            279922  Japanese
# 489515          89952  Supporting         60260            279778  Japanese
#
# [489516 rows x 5 columns]

# %%
profiles
# Out:
#            username  gender      birthday       location        joined  \
# 0         ishikawas    None          None    South Korea          None
# 1              CKK2    None          None  United States   Dec 1, 2018
# 2       --------788  Female          None         Mexico   Oct 4, 2022
# 3        potatoaris    None          None          Spain   Oct 2, 2018
# 4         Rinrintan    None          None          Japan  May 12, 2019
# ...             ...     ...           ...            ...           ...
# 337150  ariyanroy04    None          None  United States  Mar 30, 2021
# 337151   ariyanvk18    Male          None         Turkey  Jan 24, 2022
# 337152     ariyoskz    None          None        Germany   Jul 7, 2022
# 337153    arizima23  Female  Jun 23, 1998          Spain  Mar 15, 2019
# 337154      arizkim    None          None   South Africa   Dec 7, 2020
#
#        watching completed on_hold dropped plan_to_watch
# 0          None      None    None    None          None
# 1             3       182      15       0           405
# 2             1        64       0       0             1
# 3             5         1       0       0             4
# 4            20       311      40      16            34
# ...         ...       ...     ...     ...           ...
# 337150       35       130       0       0           489
# 337151        7       101       1      12            21
# 337152        1       155       2      11            15
# 337153       15        64       0       4             4
# 337154        7        38       1       0            33
#
# [337155 rows x 10 columns]

# %%
recommendations
# Out:
#         mal_id recommendation_mal_id
# 0         3269                   317
# 1         3269                  6922
# 2         3269                   299
# 3         3269                  3446
# 4         3269                  5681
# ...        ...                   ...
# 105244   31245                  1689
# 105245   31245                 35434
# 105246   31245                 31798
# 105247   31245                 21995
# 105248   36305                 42897
#
# [105249 rows x 2 columns]

# %%
stats
# Out:
#        mal_id  watching  completed  on_hold  dropped  plan_to_watch   total  \
# 0       59356         7        146        4       20             20     197
# 1       56036        21        770        8       29            113     941
# 2        2928       451      14953      302      349           6472   22527
# 3        3269       726      22790      452      537           9762   34267
# 4        4469       241       6918      182      266           3528   11135
# ...       ...       ...        ...      ...      ...            ...     ...
# 28950   59421     11349      17353      574     1440          15729   46445
# 28951   31245     10332     140676     2989     1416          94249  249662
# 28952   36305       928      16119      388      243           9656   27334
# 28953   34895       896       2387      375      356           1512    5526
# 28954   56606         4         83        2       15             20     124
#
#        score_1_votes  score_1_percentage  score_2_votes  ...  score_6_votes  \
# 0                2.0                 2.2            0.0  ...           33.0
# 1                5.0                 1.0            6.0  ...          138.0
# 2              101.0                 1.0           93.0  ...         2054.0
# 3              120.0                 0.8          156.0  ...         2457.0
# 4               83.0                 1.9          104.0  ...          888.0
# ...              ...                 ...            ...  ...            ...
# 28950           54.0                 0.3           40.0  ...         2303.0
# 28951          357.0                 0.3          484.0  ...        15972.0
# 28952           48.0                 0.5           28.0  ...         1839.0
# 28953          116.0                 6.1           80.0  ...          437.0
# 28954            3.0                 5.2            1.0  ...           15.0
#
#        score_6_percentage  score_7_votes  score_7_percentage  score_8_votes  \
# 0                    36.3           19.0                20.9            2.0
# 1                    27.4          144.0                28.6           81.0
# 2                    21.1         2709.0                27.8         1500.0
# 3                    16.0         4157.0                27.0         3075.0
# 4                    20.6          871.0                20.2          592.0
# ...                   ...            ...                 ...            ...
# 28950                14.5         5545.0                34.9         3919.0
# 28951                15.3        34370.0                33.0        24387.0
# 28952                18.3         3258.0                32.5         2009.0
# 28953                23.2          280.0                14.8          170.0
# 28954                25.9            7.0                12.1            1.0
#
#        score_8_percentage  score_9_votes  score_9_percentage  score_10_votes  \
# 0                     2.2            0.0                 0.0             1.0
# 1                    16.1           17.0                 3.4            40.0
# 2                    15.4          875.0                 9.0           608.0
# 3                    20.0         1919.0                12.5          1400.0
# 4                    13.7          308.0                 7.1           315.0
# ...                   ...            ...                 ...             ...
# 28950                24.7         1598.0                10.1          1235.0
# 28951                23.4        10480.0                10.1          7589.0
# 28952                20.0          887.0                 8.8           936.0
# 28953                 9.0           68.0                 3.6           125.0
# 28954                 1.7            0.0                 0.0             4.0
#
#        score_10_percentage
# 0                      1.1
# 1                      8.0
# 2                      6.2
# 3                      9.1
# 4                      7.3
# ...                    ...
# 28950                  7.8
# 28951                  7.3
# 28952                  9.3
# 28953                  6.6
# 28954                  6.9
#
# [28955 rows x 27 columns]

# %% [markdown]
# ### `null` values detection and removal

# %%
profiles = profiles.dropna(subset=['username'])

# %% [markdown]
# ### Duplicate rows detection and removal

# %%
print(f"Number of rows duplicated (person_voice_works): {person_voice_works.duplicated().sum()}\\n")
print(f"Number of rows duplicated (profiles): {profiles.duplicated().sum()}\\n")
print(f"Number of rows duplicated (recommendations): {recommendations.duplicated().sum()}\\n")
print(f"Number of rows duplicated (stats): {stats.duplicated().sum()}")
# Out:
# Number of rows duplicated (person_voice_works): 951\n
# Number of rows duplicated (profiles): 0\n
# Number of rows duplicated (recommendations): 0\n
# Number of rows duplicated (stats): 0

# %%
person_voice_works = person_voice_works.drop_duplicates(keep="first")
profiles = profiles.drop_duplicates(keep="first")
recommendations = recommendations.drop_duplicates(keep="first")
stats = stats.drop_duplicates(keep="first")

# %%
print(f"Number of rows duplicated (person_voice_works): {person_voice_works.duplicated().sum()}\\n")
print(f"Number of rows duplicated (profiles): {profiles.duplicated().sum()}\\n")
print(f"Number of rows duplicated (recommendations): {recommendations.duplicated().sum()}\\n")
print(f"Number of rows duplicated (stats): {stats.duplicated().sum()}")
# Out:
# Number of rows duplicated (person_voice_works): 0\n
# Number of rows duplicated (profiles): 0\n
# Number of rows duplicated (recommendations): 0\n
# Number of rows duplicated (stats): 0

# %% [markdown]
# ### Typo correction

# %%
person_voice_works = person_voice_works.copy()
recommendations = recommendations.copy()

person_voice_works.loc[:, 'role'] = person_voice_works['role'].astype('category')

# %% [markdown]
# ### Saving in cleaned csv files

# %%
rsc.save_data(person_voice_works, 'person_voice_works_cleaned', engine)
rsc.save_data(profiles, 'profiles_cleaned', engine)
rsc.save_data(recommendations, 'recommendations_cleaned', engine)
rsc.save_data(stats, 'stats_cleaned', engine)
# Out:
# Successo: 488565 righe caricate nella tabella 'person_voice_works_cleaned'.
# Successo: 337154 righe caricate nella tabella 'profiles_cleaned'.
# Successo: 105249 righe caricate nella tabella 'recommendations_cleaned'.
# Successo: 28955 righe caricate nella tabella 'stats_cleaned'.
