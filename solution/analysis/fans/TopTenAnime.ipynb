# %% [markdown]
# # Top Ten anime analysis (Fans)

# %%
import pandas as pd

favs = pd.read_csv("../../../cleaned_data/favs_cleaned.csv")
details = pd.read_csv("../../../cleaned_data/details_cleaned.csv")

# %%
topAnime = pd.merge(details, favs, left_on="mal_id", right_on= "id")
topAnimeFans = topAnime.sort_values(by="favorites", ascending=False)
topAnimeFans = topAnimeFans.drop_duplicates(subset=['title'])
topAnimeFans
# Out:
#          Unnamed: 0_x  mal_id  \
# 1750303         17919      21
# 669602           6593    5114
# 986182           9671   11061
# 2370088         23288    9253
# 2156283         22010   16498
# ...               ...     ...
# 2807473         28919   27405
# 2807467         28916   40695
# 2807480         28929   43819
# 2807500         28935   35099
# 2807498         28934   28543
#
#                                                      title  \
# 1750303                                          One Piece
# 669602                    Fullmetal Alchemist: Brotherhood
# 986182                              Hunter x Hunter (2011)
# 2370088                                        Steins;Gate
# 2156283                                 Shingeki no Kyojin
# ...                                                    ...
# 2807473                        Zou no Senaka: Tabidatsu Hi
# 2807467                                         Zou da Zou
# ...

# %% [markdown]
# In sintesi:
# Sì, la logica è quella che stai usando, ma assicurati di:
#
#
# Filtrare i dati per rispondere a bisogni reali (giornalisti vs fan).
# +1
#
#
# Aggregare (usando groupby e mean/count) per creare statistiche.
#
#
# Preparare i dati per la visualizzazione grafica finale.
