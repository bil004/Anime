# %% [markdown]
# # Evoluzione della qualità
# Come sono cambiati i voti medi (Ratings.csv) degli anime nel corso degli anni (collegando ai dati temporali degli anime)? C'è stato un "periodo d'oro"?

# %%
import pandas as pd
from solution import readSaveCsv

ratings = readSaveCsv.load_csv_file("../../../cleaned_data/ratings_cleaned.csv")
details = pd.read_csv("../../../cleaned_data/details_cleaned.csv")

ratings
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 from solution import readSaveCsv
# ----> 4 ratings = readSaveCsv.load_csv_file("../../../cleaned_data/ratings_cleaned.csv")
#       5 details = pd.read_csv("../../../cleaned_data/details_cleaned.csv")
#       7 ratings
#
# File ~\Desktop\Files\Unito\3\HCI\Anime\solution\readSaveCsv.py:8, in load_csv_file(file)
#       7 def load_csv_file(file):
# ----> 8     return pd.read_csv(file)
#
# ...
